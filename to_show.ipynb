# %% [markdown]
# # Welcome to Jupyter!

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pl
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

dat = pd.read_csv('all_combined.csv')

dat['my_wt']=dat['wow_bw_Nov']-dat['wow_bw_Aug']

s = dat['Sulfur']#
#        np.random.randint(0,50,size=305)
u = dat['Urea']#np.random.randint(0,50,size=305)
p = dat['P']#np.random.randint(0,50,size=305)
lwg = [x + np.abs(dat['my_wt'].min()) for x in dat['my_wt']]#np.random.sample(305)*20
lwg = [0.001*(x**2) for x in lwg]


fig = pl.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

#for i in range(len(s)):
plot=ax.scatter(s,u,p,s=lwg,c=lwg,marker='o',cmap='viridis',alpha=0.5)
ax.set_xlabel('Sulphur Intake')
ax.set_ylabel('Phosphorus Intake')
ax.set_zlabel('Urea Intake')

pl.suptitle('Liveweight Gain with Supplement Intake')

cbar = fig.colorbar(plot)
cbar.set_label("Liveweight gain")#, labelpad=-40)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
pl.figure()
pl.subplot(1,3,1)
pl.plot(s,lwg,'ro')
pl.ylabel('LWG')
pl.xlabel('Sulfur')
pl.subplot(1,3,2)
pl.plot(p,lwg,'bo')
pl.ylabel('LWG')
pl.xlabel('Phos.')
pl.subplot(1,3,3)
pl.plot(u,lwg,'ko')
pl.ylabel('LWG')
pl.xlabel('Urea')
pl.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pl.figure()
pl.subplot(1,3,1)
ax=pl.gca()
plot=ax.scatter(s,p,s=lwg,c=lwg,marker='o',cmap='viridis',alpha=0.5)
pl.ylabel('Phos.')
pl.xlabel('Sulf')
pl.subplot(1,3,2)
ax=pl.gca()
plot=ax.scatter(u,p,s=lwg,c=lwg,marker='o',cmap='viridis',alpha=0.5)
pl.ylabel('Phos.')
pl.xlabel('Urea')
pl.subplot(1,3,3)
ax=pl.gca()
plot=ax.scatter(u,s,s=lwg,c=lwg,marker='o',cmap='viridis',alpha=0.5)
pl.ylabel('Sulf')
pl.xlabel('Urea')


pl.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook
